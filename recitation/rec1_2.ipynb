# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.special

# %%
n = np.linspace(1,np.power(10, 10),100)

# %%
# custom base log in numpy
# base = 1.01
# custom_log = np.log(n) / np.log(base)

# %%
# pow_cust_log = np.power(custom_log, 2)
pow_log2 = np.power(np.log2(n), 3)
pow_n = np.power(n, 2)

# %%
plt.plot(n,pow_log2, c='y')
plt.plot(n,pow_cust_log, c='b')
plt.plot(n,pow_n, c='r')
# plt.plot(n,sqrt_n, c='g')
# plt.title("Matplotlib PLot NumPy Array")
# plt.xlabel("x axis")
# plt.ylabel("y axis")
plt.show()

# %%
sqrt_n = np.sqrt(n)
sqrt_n
# Out:
# array([ 1.        ,  1.04837927,  1.0946224 ,  1.13898959,  1.18169217,
#         1.22290453,  1.26277258,  1.30141988,  1.33895212,  1.37546061,
#         1.4110248 ,  1.44571439,  1.47959089,  1.51270892,  1.54511727,
#         1.57685969,  1.60797562,  1.63850074,  1.6684675 ,  1.69790544,
#         1.72684162,  1.75530085,  1.78330597,  1.81087804,  1.83803656,
#         1.86479958,  1.89118391,  1.91720517,  1.94287796,  1.96821591,
#         1.99323179,  2.01793758,  2.04234453,  2.06646323,  2.09030365,
#         2.11387523,  2.13718683,  2.1602469 ,  2.18306339,  2.20564387,
#         2.2279955 ,  2.25012512,  2.27203921,  2.29374394,  2.31524521,
#         2.33654862,  2.35765955,  2.37858312,  2.39932423,  2.41988757,
#         2.44027764,  2.46049874,  2.48055501,  2.50045041,  2.52018875,
#         2.5397737 ,  2.55920877,  2.57849736,  2.59764273,  2.61664802,
#         2.63551626,  2.65425037,  2.67285318,  2.69132741,  2.70967569,
# ...
